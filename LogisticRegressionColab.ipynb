# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.linear_model import LogisticRegression

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab_Notebooks/data/Student-Pass-Fail-Data.csv')

# %%
df.head()
# Out:
#    Self_Study_Daily  Tution_Monthly  Pass_Or_Fail
# 0                 7              27             1
# 1                 2              43             0
# 2                 7              26             1
# 3                 8              29             1
# 4                 3              42             0

# %%
X=df.iloc[:,:-1].values
y=df.iloc[:,-1].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=4,test_size = 0.30)

# %%
logistic_regression = LogisticRegression()
logistic_regression.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = logistic_regression.predict(X_test)

# %%
print("Regression coefficients")
print("Theta[0]"+str(logistic_regression.intercept_))
print("Theta"+str(logistic_regression.coef_))

confusion_matrix1 = confusion_matrix(y_test, y_pred)
print()
print("Confusion Matrics")
print(confusion_matrix1)

result = classification_report(y_test,y_pred)
print()
print("Classification Results")
print(result)
# Out:
# Regression coefficients
# Theta[0][4.95737606]
# Theta[[ 2.38499984 -0.72659039]]
#
# Confusion Matrics
# [[144   8]
#  [  0 148]]
#
# Classification Results
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97       152
#            1       0.95      1.00      0.97       148
#
#     accuracy                           0.97       300
#    macro avg       0.97      0.97      0.97       300
# weighted avg       0.97      0.97      0.97       300
